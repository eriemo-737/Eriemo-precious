# %% [markdown]
# <a href="https://colab.research.google.com/github/eriemo-737/Eriemo-precious/blob/main/First_physical_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(" Precious Eriemo")
# Out:
#  Precious Eriemo

# %%
name

# %%
print ("")

# %%
print(" 14 Olabode Atewologun street")
# Out:
#  14 Olabode Atewologun street

# %%
name = "Precious Eriemo"
name = "King David"
address = ("14 Olabode Atewologun street")
address = "Sabo Lagos"
print (name)
print (address)
print (type(name))
age = 27
print (age)
print (type(age))
money = 20.15
print (type(money))
figure = age*money
print (type(figure))
print (figure)
a = age+money
print (a)
c = name+address
print (c)
inclass = False
print (type(inclass))
inclass = 370
print (inclass)
d = age*money+inclass
print (d)
a = 30
b = 4
c = (a+b)
print (c)
d = (a-b)
print (d)
c = a/b
print (c)
e = a%b
print (e)
f = a*b
print (f)
g = a**b
print (g)
I = a//b
print (I)
d = "hello"
print (d*3)
# Out:
# King David
# Sabo Lagos
# <class 'str'>
# 27
# <class 'int'>
# <class 'float'>
# <class 'float'>
# 544.05
# 47.15
# King DavidSabo Lagos
# <class 'bool'>
# 370
# 914.05
# 34
# 26
# 7.5
# 2
# 120
# 810000
# 7
# hellohellohello

# %%
name = ("Eriemo Precious Ese")
print (name)
print (type(name))
age = 27
print (age)
print (type(age))
department = ("English Education")
print (department)
print (type(department))
mathematics = 78
print (mathematics)
print (type(mathematics))
python = 82
print (python)
print (type(python))
statistics = 74
print (statistics)
print (type(statistics))
total = (mathematics+python+statistics)
print (total)
print (type(total))
average =(total/3)
print (average)
print (type(average))
highestscore = 82
print (highestscore)
print (type(highestscore))
lowestscore = 74
print (lowestscore)
print (type(lowestscore))
passed = True
print (passed)
print (type(passed))
# Out:
# Eriemo Precious Ese
# <class 'str'>
# 27
# <class 'int'>
# English Education
# <class 'str'>
# 78
# <class 'int'>
# 82
# <class 'int'>
# 74
# <class 'int'>
# 234
# <class 'int'>
# 78.0
# <class 'float'>
# 82
# <class 'int'>
# 74
# <class 'int'>
# True
# <class 'bool'>

# %%
name = "John doe"
print (name.title())
name = "John Doe"
print (name.lower())
# Out:
# John Doe
# john doe
